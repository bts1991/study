# %% [markdown]
# <img src="https://i.ibb.co/sFcTVM4/DALL-E-2023-12-28-17-48-36-Create-a-logo-using-the-simplified-design-featuring-a-sprout-and-an-upwar.png" width="100"/>
#
# ---
# -  강의 및 추가 자료 링크
# - 강의 링크: [Python 강의](#)
#
# -  소셜 미디어 및 연락처
#   - 저자 SNS: [instagram](https://www.instagram.com/ringo_data/?igsh=MTlrdW4xMzZvNTBtdw%3D%3D), [LinkedIn](https://www.linkedin.com/in/ringokwon/)
#   - 이메일: ringo.data1@gmail.com
#
# ---

# %% [markdown]
# # Index
# - 인덱스 (Index): 행을 구별하는 데 사용되는 고유한 식별자.
#
# ```python
# df.set_index('col1', inplace = True) # index 지정
# df.reset_index(inplace = True ) # 기본 정수 Index
# ```

# %%
# taxis
import seaborn as sns
df = sns.load_dataset('taxis')

# %%
df.head(1)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0  2.15
#
#    tolls  total   color      payment      pickup_zone         dropoff_zone  \
# 0    0.0  12.95  yellow  credit card  Lenox Hill West  UN/Turtle Bay South
#
#   pickup_borough dropoff_borough
# 0      Manhattan       Manhattan

# %%
df.set_index('color') # color 컬럼을 인덱스로 지정하겠다.
# Out:
#                     pickup             dropoff  passengers  distance  fare  \
# color
# yellow 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# yellow 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# yellow 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# yellow 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# yellow 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                    ...                 ...         ...       ...   ...
# green  2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# green  2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# green  2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# green  2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# green  2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#          tip  tolls  total      payment            pickup_zone  \
# color
# yellow  2.15    0.0  12.95  credit card        Lenox Hill West
# yellow  0.00    0.0   9.30         cash  Upper West Side South
# yellow  2.36    0.0  14.16  credit card          Alphabet City
# yellow  6.15    0.0  36.95  credit card              Hudson Sq
# yellow  1.10    0.0  13.40  credit card           Midtown East
# ...      ...    ...    ...          ...                    ...
# green   1.06    0.0   6.36  credit card      East Harlem North
# green   0.00    0.0  58.80  credit card                Jamaica
# green   0.00    0.0  17.30         cash    Crown Heights North
# green   0.00    0.0   6.80  credit card          East New York
# green   3.36    0.0  20.16  credit card            Boerum Hill
#
#                             dropoff_zone pickup_borough dropoff_borough
# color
# yellow               UN/Turtle Bay South      Manhattan       Manhattan
# yellow             Upper West Side South      Manhattan       Manhattan
# yellow                      West Village      Manhattan       Manhattan
# yellow                    Yorkville West      Manhattan       Manhattan
# yellow                    Yorkville West      Manhattan       Manhattan
# ...                                  ...            ...             ...
# green               Central Harlem North      Manhattan       Manhattan
# green   East Concourse/Concourse Village         Queens           Bronx
# green                     Bushwick North       Brooklyn        Brooklyn
# green       East Flatbush/Remsen Village       Brooklyn        Brooklyn
# green                    Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 13 columns]

# %%
df.set_index('color', inplace = True)

# %%
df.reset_index(inplace = True ) # 다시 정수 인덱스로 돌아는 방

# %%
df
# Out:
#        color              pickup             dropoff  passengers  distance  \
# 0     yellow 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60
# 1     yellow 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79
# 2     yellow 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37
# 3     yellow 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70
# 4     yellow 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16
# ...      ...                 ...                 ...         ...       ...
# 6428   green 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75
# 6429   green 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74
# 6430   green 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14
# 6431   green 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12
# 6432   green 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85
#
#       fare   tip  tolls  total      payment            pickup_zone  \
# 0      7.0  2.15    0.0  12.95  credit card        Lenox Hill West
# 1      5.0  0.00    0.0   9.30         cash  Upper West Side South
# 2      7.5  2.36    0.0  14.16  credit card          Alphabet City
# 3     27.0  6.15    0.0  36.95  credit card              Hudson Sq
# 4      9.0  1.10    0.0  13.40  credit card           Midtown East
# ...    ...   ...    ...    ...          ...                    ...
# 6428   4.5  1.06    0.0   6.36  credit card      East Harlem North
# 6429  58.0  0.00    0.0  58.80  credit card                Jamaica
# 6430  16.0  0.00    0.0  17.30         cash    Crown Heights North
# 6431   6.0  0.00    0.0   6.80  credit card          East New York
# 6432  15.0  3.36    0.0  20.16  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %% [markdown]
# # Sort
# - 특정 기준에 따라 순서대로 `나열`
# - sort_value():특정 column 기준
# ```python
# df.sort_values('col1', ascending = False, inplace = True )
# ```
#   - ascending = False: 내림차순
#   - ascending = True: 오름차순
#
# - sort_index(): index 기준
# ```python
# df.sort_index(inplace= True)
# ```

# %%
df.sort_values('distance', ascending = False, inplace = True )

# %%
df.head(10)
# Out:
#        color              pickup             dropoff  passengers  distance  \
# 5364  yellow 2019-03-17 16:59:17 2019-03-17 18:04:08           2     36.70
# 4219  yellow 2019-03-08 20:07:54 2019-03-08 21:10:00           1     36.66
# 4050  yellow 2019-03-13 14:05:19 2019-03-13 15:01:16           6     33.76
# 5648   green 2019-03-19 14:21:35 2019-03-19 15:51:28           2     33.46
# 2397  yellow 2019-03-21 18:56:59 2019-03-21 19:49:58           1     30.23
# 1535  yellow 2019-03-09 18:57:53 2019-03-09 19:49:53           1     28.30
# 3875  yellow 2019-03-30 17:07:48 2019-03-30 18:10:46           6     28.15
# 4218  yellow 2019-03-29 17:32:20 2019-03-29 18:53:52           1     26.92
# 2231  yellow 2019-03-11 10:17:31 2019-03-11 11:03:55           1     26.35
# 5567   green 2019-03-07 00:28:57 2019-03-07 02:02:55           1     25.51
#
#        fare    tip  tolls   total      payment               pickup_zone  \
# 5364  150.0   0.00  24.02  174.82         cash               JFK Airport
# 4219   96.5  10.00   5.76  113.56  credit card               JFK Airport
# 4050  143.5   0.00   0.00  144.30         cash         LaGuardia Airport
# 5648  150.0   0.00  18.90  169.70         cash             East Flushing
# 2397   52.0  13.11   5.76   78.67  credit card               JFK Airport
# 1535   52.0   2.00   5.76   63.06  credit card        World Trade Center
# 3875   52.0  12.46   9.50   74.76  credit card  Financial District North
# 4218   75.5  23.19   0.00  100.49  credit card               JFK Airport
# 2231  130.0   0.00   5.76  136.56         cash         East Harlem North
# 5567   93.5   0.00   0.00   94.80  credit card          Sunset Park West
#
#                        dropoff_zone pickup_borough dropoff_borough
# 5364                    JFK Airport         Queens          Queens
# 4219                            NaN         Queens             NaN
# 4050                            NaN         Queens             NaN
# 5648                            NaN         Queens             NaN
# 2397  Meatpacking/West Village West         Queens       Manhattan
# 1535                    JFK Airport      Manhattan          Queens
# 3875                    JFK Airport      Manhattan          Queens
# 4218                    Cobble Hill         Queens        Brooklyn
# 2231                            NaN      Manhattan             NaN
# 5567                   Saint Albans       Brooklyn          Queens

# %%
df.sort_index(inplace= True) ## 다시 index 정렬로 복귀

# %%
df.head(10)
# Out:
#     color              pickup             dropoff  passengers  distance  fare  \
# 0  yellow 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1  yellow 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2  yellow 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3  yellow 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4  yellow 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5  yellow 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6  yellow 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# 7  yellow 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5
# 8  yellow 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0
# 9  yellow 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0
#
#     tip  tolls  total      payment                pickup_zone  \
# 0  2.15    0.0  12.95  credit card            Lenox Hill West
# 1  0.00    0.0   9.30         cash      Upper West Side South
# 2  2.36    0.0  14.16  credit card              Alphabet City
# 3  6.15    0.0  36.95  credit card                  Hudson Sq
# 4  1.10    0.0  13.40  credit card               Midtown East
# 5  2.16    0.0  12.96  credit card  Times Sq/Theatre District
# 6  2.00    0.0  18.80  credit card          Battery Park City
# 7  0.00    0.0  11.80          NaN                Murray Hill
# 8  1.00    0.0  19.30  credit card          East Harlem South
# 9  1.00    0.0  13.30  credit card        Lincoln Square East
#
#               dropoff_zone pickup_borough dropoff_borough
# 0      UN/Turtle Bay South      Manhattan       Manhattan
# 1    Upper West Side South      Manhattan       Manhattan
# 2             West Village      Manhattan       Manhattan
# 3           Yorkville West      Manhattan       Manhattan
# 4           Yorkville West      Manhattan       Manhattan
# 5             Midtown East      Manhattan       Manhattan
# 6  Two Bridges/Seward Park      Manhattan       Manhattan
# 7                 Flatiron      Manhattan       Manhattan
# 8           Midtown Center      Manhattan       Manhattan
# 9             Central Park      Manhattan       Manhattan

# %% [markdown]
# # Exercise
# - 일시정지 후 스스로 문제를 풀어보고 강의를 수강해 주세요

# %% [markdown]
# 1. 문제: 아래는 상품 판매 기록을 나타내는 데이터프레임을 생성하는 코드입니다. 이 데이터프레임을 사용하여 다음 작업을 수행하세요.
#
# ```python
#
# import pandas as pd
#
# # 데이터프레임 생성
# data = {
#     'ProductID': [101, 102, 103, 104],
#     'SaleDate': ['2021-07-01', '2021-07-03', '2021-07-02', '2021-07-04'],
#     'Quantity': [3, 2, 5, 4]
# }
#
# df = pd.DataFrame(data)
# ```
#
# - ProductID를 데이터프레임의 인덱스로 설정하세요.
# - Quantity를 기준으로 데이터를 내림차순으로 정렬하세요.
# - 정렬된 데이터프레임의 인덱스를 기본 인덱스로 재설정하세요.

# %%
import pandas as pd

# 데이터프레임 생성
data = {
    'ProductID': [101, 102, 103, 104],
    'SaleDate': ['2021-07-01', '2021-07-03', '2021-07-02', '2021-07-04'],
    'Quantity': [3, 2, 5, 4]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    ProductID    SaleDate  Quantity
# 0        101  2021-07-01         3
# 1        102  2021-07-03         2
# 2        103  2021-07-02         5
# 3        104  2021-07-04         4

# %%
df.set_index('ProductID', inplace = True)

# %%
df
# Out:
#              SaleDate  Quantity
# ProductID
# 101        2021-07-01         3
# 102        2021-07-03         2
# 103        2021-07-02         5
# 104        2021-07-04         4

# %%
df.sort_values('Quantity', ascending = False, inplace = True )

# %%
df
# Out:
#              SaleDate  Quantity
# ProductID
# 103        2021-07-02         5
# 104        2021-07-04         4
# 101        2021-07-01         3
# 102        2021-07-03         2

# %%
df.reset_index(inplace = True )

# %%
df
# Out:
#    ProductID    SaleDate  Quantity
# 0        103  2021-07-02         5
# 1        104  2021-07-04         4
# 2        101  2021-07-01         3
# 3        102  2021-07-03         2

# %% [markdown]
# ---
# -  🔒 저작권 및 사용 조건 (중요)
#   - **저작권 보호**: 이 강의 노트는 저작권법에 의해 엄격히 보호됩니다.
#   - **무단 사용 금지**: 어떠한 형태로든 상업적 사용이 엄격히 금지됩니다.
#   - **개인용도 한정**: 이 자료는 교육 목적으로만 사용이 허가되며, 개인적인 학습 외의 목적으로 사용할 수 없습니다.
#   - **위반 시 조치**: 저작권법 위반 시 법적 조치가 취해질 수 있습니다.
# ---
#
# <img src="https://i.ibb.co/sFcTVM4/DALL-E-2023-12-28-17-48-36-Create-a-logo-using-the-simplified-design-featuring-a-sprout-and-an-upwar.png" width="100"/>
