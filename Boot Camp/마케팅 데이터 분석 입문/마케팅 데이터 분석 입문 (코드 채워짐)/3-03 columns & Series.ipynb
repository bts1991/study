# %% [markdown]
# <img src="https://i.ibb.co/sFcTVM4/DALL-E-2023-12-28-17-48-36-Create-a-logo-using-the-simplified-design-featuring-a-sprout-and-an-upwar.png"
# width="100"/>
#
# ---
# -  강의 및 추가 자료 링크
# - 강의 링크: [Python 강의](#)
#
# -  소셜 미디어 및 연락처
#   - 저자 SNS: [instagram](https://www.instagram.com/ringo_data/?igsh=MTlrdW4xMzZvNTBtdw%3D%3D), [LinkedIn](https://www.linkedin.com/in/ringokwon/)
#   - 이메일: ringo.data1@gmail.com
#
# ---

# %% [markdown]
# # column 선택
# - 단일 column 선택
# ```python
# df.age
# df['age'] # 안정적
# ```
# - 다중 column 선택
# ```python
# df[['age','name']]
# ```

# %%
# 다양한 column 선택의 방법

import seaborn as sns
df_iris = sns.load_dataset('iris')

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris[['sepal_length']]
# Out:
#      sepal_length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %%
df_iris[['sepal_length', 'species']] ## 컬럼을 2개 이상 가지고 오려면 대괄호 안에 리스트를 넣어야
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
#변수를 활용한 다중 column 선택

df_iris.head()
col_selected = ['sepal_length', 'sepal_width']
df_iris[col_selected]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
# 다중 선택과 df 파악

# %% [markdown]
# #column 수정하기

# %% [markdown]
# ## column 삭제: drop()
# ```python
# df.drop( labels = 'col1', axis = 1 , inplace = True  )
# # axis = 1: 대상이 column
# # inplace = True: 원본 df 변경
# ```

# %%
df_iris.head()
# Out:
#      A    B  petal_length  petal_width species  A_plus_B
# 0  5.1  3.5           1.4          0.2  setosa       8.6
# 1  4.9  3.0           1.4          0.2  setosa       7.9
# 2  4.7  3.2           1.3          0.2  setosa       7.9
# 3  4.6  3.1           1.5          0.2  setosa       7.7
# 4  5.0  3.6           1.4          0.2  setosa       8.6

# %%
df_iris['new_col'] = df_iris.sepal_length * 3

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  new_col
# 0             5.1          3.5           1.4          0.2     setosa     15.3
# 1             4.9          3.0           1.4          0.2     setosa     14.7
# 2             4.7          3.2           1.3          0.2     setosa     14.1
# 3             4.6          3.1           1.5          0.2     setosa     13.8
# 4             5.0          3.6           1.4          0.2     setosa     15.0
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica     20.1
# 146           6.3          2.5           5.0          1.9  virginica     18.9
# 147           6.5          3.0           5.2          2.0  virginica     19.5
# 148           6.2          3.4           5.4          2.3  virginica     18.6
# 149           5.9          3.0           5.1          1.8  virginica     17.7
#
# [150 rows x 6 columns]

# %%
df_iris.drop( labels = 'new_col', axis = 1 , inplace = True  )

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## column명 변경: rename()
# ```python
# df.rename( columns = {'col1': 'new_col1', 'col2': 'new_col2'}, inplace = True )
# # {'col1': 'new_col1', 'col2': 'new_col2'} <-Dintionary
# ```

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.rename( columns = {'sepal_length': 'A', 'sepal_width': 'B'}, inplace = True )
# {'col1': 'new_col1', 'col2': 'new_col2'} <-Dintionary

# %%
df_iris.head()
# Out:
#      A    B  petal_length  petal_width species
# 0  5.1  3.5           1.4          0.2  setosa
# 1  4.9  3.0           1.4          0.2  setosa
# 2  4.7  3.2           1.3          0.2  setosa
# 3  4.6  3.1           1.5          0.2  setosa
# 4  5.0  3.6           1.4          0.2  setosa

# %% [markdown]
# ## column 추가
# ```python
# df['new_col'] = existing_series
# ```

# %%
df_iris['A_plus_B'] = df_iris.A + df_iris.B

# %%
df_iris.head()
# Out:
#      A    B  petal_length  petal_width species  A_plus_B
# 0  5.1  3.5           1.4          0.2  setosa       8.6
# 1  4.9  3.0           1.4          0.2  setosa       7.9
# 2  4.7  3.2           1.3          0.2  setosa       7.9
# 3  4.6  3.1           1.5          0.2  setosa       7.7
# 4  5.0  3.6           1.4          0.2  setosa       8.6

# %% [markdown]
# # Series
# - DataFrame 에서 하나의 column 만 선택하면 series

# %%
#type ()

type(df_iris.A)
# Out:
# pandas.core.series.Series

# %%
# 기본 집계 min, max, sum, mean

df_iris.A.mean()
# Out:
# 5.843333333333334

# %% [markdown]
# - unique(): 중복 없는 값들 나열.
# - nunique(): 중복 없는 값들 수 세기.

# %%
# unique, nunique

df_iris.A.nunique()
# Out:
# 35

# %%
# value_counts 각 값들이 몇개씩 있는지

df_iris.A.value_counts()
# Out:
# A
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %% [markdown]
# # nlargest(), nsmallest()
# ```python
# df.nlargest(number,['col1','col2',...])
# ```

# %%
# nlargest 다중 나열

# df_iris.A.nlargest(10)
df_iris.nlargest(10, ['A', 'B'])
# Out:
#        A    B  petal_length  petal_width    species  A_plus_B
# 131  7.9  3.8           6.4          2.0  virginica      11.7
# 117  7.7  3.8           6.7          2.2  virginica      11.5
# 135  7.7  3.0           6.1          2.3  virginica      10.7
# 122  7.7  2.8           6.7          2.0  virginica      10.5
# 118  7.7  2.6           6.9          2.3  virginica      10.3
# 105  7.6  3.0           6.6          2.1  virginica      10.6
# 130  7.4  2.8           6.1          1.9  virginica      10.2
# 107  7.3  2.9           6.3          1.8  virginica      10.2
# 109  7.2  3.6           6.1          2.5  virginica      10.8
# 125  7.2  3.2           6.0          1.8  virginica      10.4

# %% [markdown]
# # value_counts()
# - value_counts(): 각 값 별로 개수 세기.

# %%
# column 하나

df_iris['A'].value_counts().head()
# Out:
# A
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# Name: count, dtype: int64

# %%
# column 두개

df_iris[['A', 'B']].value_counts().head()
# Out:
# A    B
# 5.8  2.7    4
# 5.1  3.8    3
# 6.5  3.0    3
# 6.9  3.1    3
# 6.7  3.1    3
# Name: count, dtype: int64

# %%
# plot() bar 차트

df_iris['A'].value_counts().head().plot(kind = 'bar')
# Out:
# <Axes: xlabel='A'>

# %% [markdown]
# # Exercise
# - 일시정지 후 스스로 문제를 풀어보고 강의를 수강해 주세요

# %% [markdown]
# 1. iris 를 sns를 활용하여 불러오시요
#   - unique(), nunique() 활용하여 species column이 어떤 값을 가지는지 파악 하시오
#   - value_counts()와 plot()을 활용하여 species의 수를 보여주는 bar 그래프를 그리시오

# %%
import seaborn as sns
df_iris2 = sns.load_dataset('iris')

# %%
df_iris2.species.unique()
df_iris2.species.nunique()
# Out:
# 3

# %%
df_iris2.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df_iris2.species.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# 2. 데이터셋 설명
# - 데이터셋은 가상의 온라인 상점의 고객 주문 내역을 포함하고 있다고 가정합니다. 데이터셋에는 다음과 같은 컬럼이 있습니다:
#
#   - CustomerID: 고객의 고유 ID
#   - OrderDate: 주문 날짜
#   - Product: 구매한 상품명
#   - Quantity: 구매한 상품의 수량
#   - Price: 상품의 가격
# - 예제 작업
#   - 컬럼 이름 변경: CustomerID 컬럼의 이름을 ID로 변경하세요.
#   - 컬럼 삭제: OrderDate 컬럼을 삭제하세요.
#   - 새 컬럼 추가: 각 주문의 총 금액을 나타내는 TotalAmount라는 새 컬럼을 추가하세요. 이 컬럼은 Quantity와 Price의 곱으로 계산됩니다.
#
# ```python
# import pandas as pd
#
# # 예제 데이터프레임 생성
# data = {
#     'CustomerID': [101, 102, 103, 104],
#     'OrderDate': ['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04'],
#     'Product': ['Apple', 'Banana', 'Cherry', 'Date'],
#     'Quantity': [5, 3, 4, 2],
#     'Price': [100,200,250,50]
# }
#
# df = pd.DataFrame(data)
# ```

# %%
import pandas as pd

# 예제 데이터프레임 생성
data = {
    'CustomerID': [101, 102, 103, 104],
    'OrderDate': ['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04'],
    'Product': ['Apple', 'Banana', 'Cherry', 'Date'],
    'Quantity': [5, 3, 4, 2],
    'Price': [100,200,250,50]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    CustomerID   OrderDate Product  Quantity  Price
# 0         101  2021-01-01   Apple         5    100
# 1         102  2021-01-02  Banana         3    200
# 2         103  2021-01-03  Cherry         4    250
# 3         104  2021-01-04    Date         2     50

# %%
from os import rename
#컬럼 이름 변경: CustomerID 컬럼의 이름을 ID로 변경하세요.
df.rename(columns = {'CustomerID': 'ID'}, inplace = True)

# %%
df
# Out:
#     ID   OrderDate Product  Quantity  Price
# 0  101  2021-01-01   Apple         5    100
# 1  102  2021-01-02  Banana         3    200
# 2  103  2021-01-03  Cherry         4    250
# 3  104  2021-01-04    Date         2     50

# %%
#컬럼 삭제: OrderDate 컬럼을 삭제하세요.
df.drop(labels = 'OrderDate', axis = 1, inplace = True)

# %%
df
# Out:
#     ID Product  Quantity  Price
# 0  101   Apple         5    100
# 1  102  Banana         3    200
# 2  103  Cherry         4    250
# 3  104    Date         2     50

# %%
#새 컬럼 추가: 각 주문의 총 금액을 나타내는 TotalAmount라는 새 컬럼을 추가하세요.
# 이 컬럼은 Quantity와 Price의 곱으로 계산됩니다.
df['TotalAmount'] = df.Quantity * df.Price

# %%
df
# Out:
#     ID Product  Quantity  Price  TotalAmount
# 0  101   Apple         5    100          500
# 1  102  Banana         3    200          600
# 2  103  Cherry         4    250         1000
# 3  104    Date         2     50          100

# %% [markdown]
# ---
# -  🔒 저작권 및 사용 조건 (중요)
#   - **저작권 보호**: 이 강의 노트는 저작권법에 의해 엄격히 보호됩니다.
#   - **무단 사용 금지**: 어떠한 형태로든 상업적 사용이 엄격히 금지됩니다.
#   - **개인용도 한정**: 이 자료는 교육 목적으로만 사용이 허가되며, 개인적인 학습 외의 목적으로 사용할 수 없습니다.
#   - **위반 시 조치**: 저작권법 위반 시 법적 조치가 취해질 수 있습니다.
# ---
# <img src="https://i.ibb.co/sFcTVM4/DALL-E-2023-12-28-17-48-36-Create-a-logo-using-the-simplified-design-featuring-a-sprout-and-an-upwar.png" width="100"/>
